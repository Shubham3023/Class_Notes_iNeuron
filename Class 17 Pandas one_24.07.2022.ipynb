# %%
import pandas as pd

# %%
"""to remove unicode error usr r or s or \\ before address
pd.read_excel(r'Attribute DataSet.xlsx')
"""
# Out:
# "to remove unicode error usr r or s or \\ before address\npd.read_excel(r'Attribute DataSet.xlsx')\n"

# %%
df = pd.read_excel('Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df) # dataframe is equivalent to table while series is equivalent to list in pandas, NaN is null value
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel('Attribute DataSet.xlsx',sheet_name= 'Sheet2' )
# Out:
#    gdsffdg     fg     dfg    fdg
# 0     dsfg  dfgdf     fdg    fdg
# 1     dfgv      g     dfg    dfg
# 2     dsfg  dfgdf     dfg   dafg
# 3      vsd  dfgdf     dfg    afd
# 4     vsdv  dfgdf     dfg    gdf
# 5        v  dfgdf     dfg    gdf
# 6       xc  dfgdf  dfgadf    gdf
# 7        v    gdf      ga    gds
# 8     xvsd    gdf      dg     fg
# 9      gsd    gdf    adfg  dsfgd
# 10   gfdsg    gdf    adfg   fgdf
# 11    dfgv      g    dfag      g

# %%
pd.read_excel('Attribute DataSet.xlsx',sheet_name= 'Sheet3', header= None, names= ['A','B','C','D','E'] )
# Out:
#       A     B     C     D       E
# 0  gdfg   NaN   NaN   NaN     NaN
# 1   NaN     g    fg  ggdf     NaN
# 2  gdfg   NaN    fg   NaN  sdfsdf
# 3    df     g   NaN    df     NaN
# 4   NaN   NaN    df     g       g
# 5   NaN  gdfg   gdf   NaN     NaN
# 6  gdfg   NaN   NaN  gfdg   fdgdf
# 7   NaN    gg  dgdf   gdf     NaN

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.head(2) # if nothing mentioned first 5 records are shown
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.tail(2)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
pd.read_csv('haberman.csv',header = None, names= ['Age', "Patient's year of operation","Number of positive","Survival status"])
# Out:
#      Age  Patient's year of operation  Number of positive  Survival status
# 0     30                           64                   1                1
# 1     30                           62                   3                1
# 2     30                           65                   0                1
# 3     31                           59                   2                1
# 4     31                           65                   4                1
# ..   ...                          ...                 ...              ...
# 301   75                           62                   1                1
# 302   76                           67                   0                1
# 303   77                           65                   3                1
# 304   78                           65                   1                2
# 305   83                           58                   2                2
#
# [306 rows x 4 columns]

# %%
pd.read_csv('haberman1.csv', header= None)
# Out:
#              0
# 0    30@64@1@1
# 1    30@62@3@1
# 2    30@65@0@1
# 3    31@59@2@1
# 4    31@65@4@1
# ..         ...
# 301  75@62@1@1
# 302  76@67@0@1
# 303  77@65@3@1
# 304  78@65@1@2
# 305  83@58@2@2
#
# [306 rows x 1 columns]

# %%
pd.read_csv('haberman1.csv', sep='@',header= None)
# Out:
#       0   1  2  3
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BCF.csv')
# Out:
#            date  values.I2P  values.P2I  values.JPI
# 0    1996-04-01   -2.580556   -0.836444        63.3
# 1    1996-05-01   -2.882258   -1.972581        66.3
# 2    1996-06-01   -1.742778   -0.478778        59.7
# 3    1996-07-01   -0.397796   -1.574301        63.3
# 4    1996-08-01   -0.977151   -1.797312        63.8
# ..          ...         ...         ...         ...
# 112  2005-08-01   -2.144935   -1.646989        49.0
# 113  2005-09-01   -3.543270   -1.769889        49.9
# 114  2005-10-01   -4.500484   -2.309946        50.6
# 115  2005-11-01   -4.098556   -1.528611        57.4
# 116  2005-12-01   -5.797043   -2.872849        52.9
#
# [117 rows x 4 columns]

# %%
a = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
a
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(a) # html read will create list of all tables(dataframes)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# json reading

# %%
 js = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
js['user']
# Out:
# 0     {'login': 'dataxerik', 'id': 15721311, 'node_i...
# 1     {'login': 'kouml', 'id': 23252616, 'node_id': ...
# 2     {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 3     {'login': 'behrenhoff', 'id': 1408034, 'node_i...
# 4     {'login': 'msilva-pass', 'id': 91082605, 'node...
# 5     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 6     {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 7     {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 8     {'login': 'rgommers', 'id': 98330, 'node_id': ...
# 9     {'login': 'asandeep', 'id': 1650682, 'node_id'...
# 10    {'login': 'mmiller-max', 'id': 59854849, 'node...
# 11    {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 12    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 13    {'login': 'VHElise', 'id': 1756220, 'node_id':...
# 14    {'login': 'JeffersonQin', 'id': 30655701, 'nod...
# 15    {'login': 'daviewales', 'id': 2499066, 'node_i...
# 16    {'login': 'bbizarro', 'id': 9373954, 'node_id'...
# ...

# %%
js['user'][0]
# Out:
# {'login': 'dataxerik',
#  'id': 15721311,
#  'node_id': 'MDQ6VXNlcjE1NzIxMzEx',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/15721311?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/dataxerik',
#  'html_url': 'https://github.com/dataxerik',
#  'followers_url': 'https://api.github.com/users/dataxerik/followers',
#  'following_url': 'https://api.github.com/users/dataxerik/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/dataxerik/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/dataxerik/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/dataxerik/subscriptions',
#  'organizations_url': 'https://api.github.com/users/dataxerik/orgs',
#  'repos_url': 'https://api.github.com/users/dataxerik/repos',
#  'events_url': 'https://api.github.com/users/dataxerik/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/dataxerik/received_events',
#  'type': 'User',
# ...

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_json('test.json')

# %%
pwd
# Out:
# 'C:\\Users\\Shubham'

# %%
df.to_csv("D:\\test1.csv")

# %%
df.to_html("D:\\test112.html")

# %%
df.to_csv("D:\\test1sep.csv", sep= "#")

# %%
# to remove row indexs

# %%
df.to_csv("D:\\test1noindex.csv", index= False)

# %%
My sql: using a python
    1. Create a table for attribute dataset and dress dataset. 
    2. Do a bulk load for these two table for respective dataset.
    3. Read these dataset in pandas as a dataframe.
    4. Convert attribute dataset in jason format.
    5. Store this data set into mongo db.
    6. In sql task try to perform left join operation with attribute dataset and dress dateset on column dress id.
    7. Write a sql query to find out how many unique dress that we have based on dress id.
    8. Try to find out how many dress is having recommendation 0.
    9. Try to find out total dress sell for individual dress id.
    10. Try to find out third highest most selling dress.
