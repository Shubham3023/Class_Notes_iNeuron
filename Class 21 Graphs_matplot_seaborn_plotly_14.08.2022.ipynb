# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.plot(figsize = (12,8))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area', stacked = False)
# Out:
# <AxesSubplot:>

# %%
#check missing from sirs sheet

# %%
df.plot.scatter(x = 'sepal_length', y = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s= 80)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s= df['petal_width']*100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 25)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 25, cmap = 'viridis')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
from mpl_toolkits import mplot3d

# %%
x = np.linspace(-1,6, (30))
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y = np.linspace(-1,6, 30)
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
def sin_un(x,y) :
    return np.sin(np.sqrt(x**2 + y**2))

# %%
z = x +y

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(df['sepal_length'],df['sepal_width'],df['petal_length'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_zlabel('petal_length')
# Out:
# Text(0.5, 0, 'petal_length')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:10]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
df.iloc[5:10].plot(kind = 'bar', figsize = (15,5)) #bar graph is used to do comparision row wise whereas line graph is used for column wise comparasion
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:10].plot(kind = 'barh', figsize = (15,5))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'hist', figsize = (15,8)) # it is basically groupby count
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize= (20,10), color = '#38CC77', alpha = 0.8) # alpha controls contrast/ density of color
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.set_config_file(theme='polar')
df.iplot()
# Out:
# <div>                            <div id="5564ad6c-3bdb-46ce-9c9f-d38acceae390" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = "sepal_length", y = 'sepal_width', kind = "scatter", mode = 'markers', xTitle = 'sepal_length', yTitle = 'sepal_width')
# Out:
# <div>                            <div id="1f0d83eb-bf9a-4a40-8df5-48b554a4957e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = "sepal_length", y = 'sepal_width', kind = "bubble",size = 'petal_width', xTitle = 'sepal_length', yTitle = 'sepal_width')
# Out:
# <div>                            <div id="8c2644b4-d286-4c4f-9966-a5ca1b82fd1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.iplot(x = "sepal_length", y = 'sepal_width',z = 'petal_length', kind = "bubble3d",size = 'sepal_length', xTitle = 'sepal_length', yTitle = 'sepal_width', zTitle = 'petal_length')
# Out:
# <div>                            <div id="27e0aea8-185e-4fb0-890e-2de45e469551" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1 = sns.load_dataset('tips')
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1.plot(x = 'total_bill', y = 'tip', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df1.iplot(x = 'total_bill', y = 'tip', kind = 'scatter', mode = 'markers', xTitle = 'total_bill', yTitle = 'tip')
# Out:
# <div>                            <div id="82817ff7-c550-46ae-bb35-0b9c1668e422" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1)

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'smoker')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'time',  style= 'smoker')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'sex', style= 'smoker') # hue and style are used for grouping

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'size')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1,col= 'time') # this is used to seperate by column names

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1,col= 'sex')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot(x = 'sepal_length', y = 'sepal_width', data = df,col= 'species')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1,col= 'day')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = df1)

# %%
sns.catplot(x = 'day', y = 'tip', data = df1) # categorical plot

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df)

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="a5cee73d-d549-42b4-97f5-95e84b1999bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2 = df1[['total_bill', 'tip','size']]
df2.scatter_matrix()
# Out:
# <div>                            <div id="5fa9656f-e8d0-4332-8e94-33a3f97c4aef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x = df1.total_bill, y = df1.tip)

# %%
sns.jointplot(x = df1.total_bill, y = df1.tip, kind = 'hex', gridsize = 20)

# %%
sns.pairplot(df1)

# %%
sns.regplot(x = df1.total_bill, y = df1.tip)
sns.set(rc={'figure.figsize':(30,20)})
